# %% [markdown]
# # Lecture 2 - VS Code, Jupyter und erste Datenstrukturen
#
# Dieses Notebook begleitet die zweite Vorlesung.
#
# **Ziele heute**
# - prüfen, ob Ihre Entwicklungsumgebung funktioniert
# - den Unterschied zwischen **Conda-Umgebung**, **Python-Interpreter** und **Kernel** verstehen
# - in VS Code zwischen **Skript**, **Markdown** und **Jupyter-Notebook** unterscheiden
# - erste Übungen zu **Markdown**, **Rechnen**, **Variablen**, **Datentypen**, **Vektoren**, **Matrizen** und **pandas** bearbeiten
#
# > Wählen Sie oben rechts als Kernel möglichst die Kursumgebung aus.

# %% [markdown]
# ## 1. Dev-Environment-Check
#
# Führen Sie die nächsten beiden Zellen aus.
# Wenn beide ohne Fehlermeldung laufen, ist Ihr Setup in einem guten Zustand.

# %%
import sys
print("Python executable:")
print(sys.executable)
# Out:
# Python executable:
# c:\Users\martin\anaconda3\python.exe

# %%
import pandas as pd
print("pandas version:", pd.__version__)
# Out:
# pandas version: 2.2.3

# %% [markdown]
# ## 2. Begriffe zur Orientierung
#
# **Conda-Umgebung**
# Ein isolierter Arbeitsbereich mit eigener Python-Version und eigenen Paketen.
#
# **Python-Interpreter**
# Die konkrete Python-Executable, die VS Code für Skripte und viele Editor-Funktionen nutzt.
#
# **Kernel**
# Der laufende Prozess, der in einem Jupyter-Notebook Ihre Zellen ausführt.
#
# **Merksatz:**
# Interpreter und Kernel sollten möglichst aus derselben Umgebung stammen.

# %% [markdown]
# ## 3. Übung 1 - Markdown und einfache Rechenoperationen
#
# ### Aufgabe A
# Erstellen Sie **unter dieser Zelle** selbst eine neue **Markdown-Zelle** mit:
#
# - einer Überschrift
# - zwei Stichpunkten
# - einem kurzen Satz darüber, was heute schon funktioniert
#
# ### Aufgabe B
# Führen Sie die folgenden Rechenoperationen aus.

# %%
2 + 2
# Out:
# 4

# %%
10 - 3
# Out:
# 7

# %%
3 * 4
# Out:
# 12

# %%
12 / 5
# Out:
# 2.4

# %%
2 ** 3
# Out:
# 8

# %% [markdown]
# ## 4. Variablen und Datentypen
#
# Eine **Variable** ist ein Name für einen Wert.
#
# Mit `type()` können wir prüfen, zu welchem Datentyp ein Wert gehört.

# %%
stress_score = 18
motivation_score = 21
name = "Mia"
is_student = True
average = 3.75

print(stress_score)
print(motivation_score)
print(name)
print(is_student)
print(average)
# Out:
# 18
# 21
# Mia
# True
# 3.75

# %%
print(type(stress_score))
print(type(average))
print(type(name))
print(type(is_student))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>

# %% [markdown]
# ### Aufgabe
# 1. Legen Sie drei eigene Variablen an.
# 2. Geben Sie jede Variable mit `print()` aus.
# 3. Prüfen Sie den Typ jeder Variable mit `type()`.

# %%
# Ihre eigene Übung
# Beispiel:
# age = 23
# print(age)
# print(type(age))

# %% [markdown]
# ## 5. Vektoren und Matrizen
#
# Im Kurs reicht zunächst folgende Intuition:
#
# - Ein **Vektor** ist eine geordnete Reihe von Werten
# - Eine **Matrix** ist eine rechteckige Anordnung von Werten in Zeilen und Spalten
#
# Für einfache Beispiele verwenden wir `numpy`.

# %%
import numpy as np

vector = np.array([2, 4, 6, 8])
matrix = np.array([[1, 2],
                   [3, 4]])

print("Vektor:")
print(vector)
print("Form:", vector.shape)

print("\nMatrix:")
print(matrix)
print("Form:", matrix.shape)
# Out:
# Vektor:
# [2 4 6 8]
# Form: (4,)
#
# Matrix:
# [[1 2]
#  [3 4]]
# Form: (2, 2)

# %%
print("Erstes Element des Vektors:", vector[0])
print("Element in Zeile 2, Spalte 1 der Matrix:", matrix[1, 0])
print("Mittelwert des Vektors:", vector.mean())
# Out:
# Erstes Element des Vektors: 2
# Element in Zeile 2, Spalte 1 der Matrix: 3
# Mittelwert des Vektors: 5.0

# %%
print("Matrix + 1:")
print(matrix + 1)

print("\nMatrix mal 2:")
print(matrix * 2)
# Out:
# Matrix + 1:
# [[2 3]
#  [4 5]]
#
# Matrix mal 2:
# [[2 4]
#  [6 8]]

# %% [markdown]
# ### Aufgabe
# - Erstellen Sie einen eigenen Vektor mit vier Zahlen.
# - Erstellen Sie eine eigene 2x2-Matrix.
# - Geben Sie jeweils die `shape` aus.

# %%
# Ihre eigene Übung zu Vektor und Matrix

# %% [markdown]
# ## 6. Skript, Markdown und Notebook
#
# ### Python-Skript (`.py`)
# - enthält nur Code
# - eignet sich gut für kompaktere Programme
#
# ### Markdown
# - enthält strukturierten Text
# - eignet sich für Überschriften, Notizen und Dokumentation
#
# ### Jupyter-Notebook (`.ipynb`)
# - verbindet Code, Text und direkte Ausgabe
# - eignet sich gut zum Lernen, Explorieren und Kommentieren

# %% [markdown]
# ## 7. pandas und tabellarische Daten
#
# `pandas` ist eine wichtige Bibliothek für tabellarische Daten.
#
# Ein **DataFrame** ist eine Datenstruktur mit **Zeilen** und **Spalten**.
# Das ist eine gute Brücke zu Tabellen aus Excel oder SPSS.

# %%
import pandas as pd

df = pd.DataFrame({
    "participant": [1, 2, 3, 4, 5],
    "stress": [2, 4, 5, 3, 4],
    "motivation": [4, 5, 3, 4, 2],
    "satisfaction": [3, 4, 2, 4, 3]
})

df
# Out:
#    participant  stress  motivation  satisfaction
# 0            1       2           4             3
# 1            2       4           5             4
# 2            3       5           3             2
# 3            4       3           4             4
# 4            5       4           2             3

# %%
print("Spaltennamen:", list(df.columns))
print("Anzahl Zeilen und Spalten:", df.shape)
print("Mittelwert Stress:", df["stress"].mean())
print("Mittelwert Motivation:", df["motivation"].mean())
# Out:
# Spaltennamen: ['participant', 'stress', 'motivation', 'satisfaction']
# Anzahl Zeilen und Spalten: (5, 4)
# Mittelwert Stress: 3.6
# Mittelwert Motivation: 3.6

# %%
df["difference"] = df["motivation"] - df["stress"]
df
# Out:
#    participant  stress  motivation  satisfaction  difference
# 0            1       2           4             3           2
# 1            2       4           5             4           1
# 2            3       5           3             2          -2
# 3            4       3           4             4           1
# 4            5       4           2             3          -2

# %% [markdown]
# ### Aufgabe
# 1. Berechnen Sie den Mittelwert von `satisfaction`.
# 2. Finden Sie heraus, welche Spalte den höchsten Mittelwert hat.
# 3. Fügen Sie eine neue Spalte hinzu, zum Beispiel `wellbeing`.

# %%
# Ihre eigene pandas-Übung

# %% [markdown]
# ## 8. Kurzrückblick
#
# Am Ende der Sitzung sollten Sie nun ungefähr beantworten können:
#
# - Was bedeuten die wichtigsten Bereiche in VS Code?
# - Was ist eine Conda-Umgebung?
# - Was ist ein Python-Interpreter?
# - Was ist ein Kernel?
# - Was ist ein Python-Skript?
# - Was ist Markdown?
# - Was ist ein Jupyter-Notebook?
# - Was ist eine Variable?
# - Welche einfachen Datentypen haben wir gesehen?
# - Was ist ein DataFrame in pandas?

# %% [markdown]
# ## 9. Kleine Hausaufgabe
#
# 1. Öffnen Sie dieses Notebook zu Hause noch einmal.
# 2. Führen Sie alle Zellen erneut aus.
# 3. Ergänzen Sie:
#    - eine eigene Markdown-Zelle
#    - drei eigene Variablen
#    - einen eigenen Vektor
#    - eine eigene 2x2-Matrix
#    - eine zusätzliche Spalte im DataFrame
# 4. Schreiben Sie 3 bis 5 Sätze:
#    - Was ist jetzt klarer als vor der Sitzung?
#    - Was ist noch unklar?
