# %% [markdown]
# # Übungsblatt - Vorlesung 2
#
# **Thema:** VS Code, Jupyter, Variablen, Vektoren, Matrizen und erste Schritte mit pandas
#
# Bearbeiten Sie die Aufgaben in der Reihenfolge. Notieren Sie konkrete Fehlermeldungen, wenn etwas nicht funktioniert.

# %% [markdown]
# ## Aufgabe 0 - Dev Environment Check
#
# Führen Sie die folgende Zelle aus.

# %%
import sys
import pandas as pd

print(sys.executable)
print(pd.__version__)
# Out:
# c:\Users\martin\anaconda3\python.exe
# 2.2.3

# %% [markdown]
# ## Aufgabe 1 - Begriffe kurz erklären
#
# Erstellen Sie unter dieser Zelle eine **eigene Markdown-Zelle** und erklären Sie kurz:
#
# - Conda-Umgebung
# - Python-Interpreter
# - Kernel
# - VS Code
# - Unterschied zwischen Skript, Markdown und Notebook

# %% [markdown]
# ## Aufgabe 2 - Markdown üben
#
# Erstellen Sie eine neue Markdown-Zelle mit:
#
# - einer Überschrift erster Ebene
# - einer Überschrift zweiter Ebene
# - einer Liste mit mindestens drei Punkten
# - **fetter** Formatierung
# - *kursiver* Formatierung

# %% [markdown]
# ## Aufgabe 3 - Einfache Rechnungen
#
# Legen Sie zwei Zahlenvariablen an und berechnen Sie Summe, Differenz, Produkt und Quotient.

# %%
# TODO: Zahlenvariablen anlegen
# TODO: Summe, Differenz, Produkt und Quotient berechnen
# TODO: Ergebnisse ausgeben

# %% [markdown]
# ## Aufgabe 4 - Variablen und Datentypen
#
# Legen Sie mindestens vier Variablen unterschiedlicher Typen an und prüfen Sie sie mit `type()`.

# %%
# TODO: Variablen anlegen
# TODO: Variablen ausgeben
# TODO: type() prüfen

# %% [markdown]
# Schreiben Sie darunter in einer Markdown-Zelle kurz auf, was `int`, `float`, `str` und `bool` bedeuten.

# %% [markdown]
# ## Aufgabe 5 - Vektor und Matrix
#
# Importieren Sie NumPy und arbeiten Sie mit einem Vektor und einer 2x2-Matrix.

# %%
import numpy as np

# TODO: Vektor anlegen
# TODO: v, v.shape und v.mean() ausgeben

# TODO: Matrix anlegen
# TODO: M, M.shape, M + 1 und M[1, 0] ausgeben

# %% [markdown]
# Schreiben Sie darunter in einer Markdown-Zelle kurz auf, worin für Sie der Unterschied zwischen Vektor und Matrix besteht.

# %% [markdown]
# ## Aufgabe 6 - Erster DataFrame mit pandas
#
# Erstellen Sie einen kleinen DataFrame mit mindestens fünf Zeilen und vier Spalten.

# %%
import pandas as pd

# TODO: DataFrame anlegen
# Beispielspalten: participant, stress, motivation, satisfaction

# TODO: df anzeigen
# TODO: df.shape prüfen
# TODO: df.columns prüfen
# TODO: zwei Mittelwerte berechnen
# TODO: neue Spalte hinzufügen
# TODO: df erneut anzeigen

# %% [markdown]
# Beantworten Sie darunter in einer Markdown-Zelle: Welche Spalte hat den höchsten Mittelwert?

# %% [markdown]
# ## Aufgabe 7 - Kurze Reflexion
#
# Erstellen Sie eine letzte Markdown-Zelle und beantworten Sie kurz:
#
# 1. Was war am einfachsten?
# 2. Was war noch unklar?
# 3. Wo hatten Sie technische Schwierigkeiten?
# 4. Welchen Unterschied verstehen Sie jetzt besser als vor der Sitzung?

# %% [markdown]
# ## Mindestziel
#
# - Notebook starten
# - Umgebung prüfen
# - Markdown schreiben
# - Variablen und `type()` nutzen
# - Vektor und Matrix anlegen
# - einfachen DataFrame erzeugen
