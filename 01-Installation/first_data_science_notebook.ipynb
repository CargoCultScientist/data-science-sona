# %% [markdown]
# # Erste Schritte in Python und Pandas
#
# Dieses Notebook begleitet die erste Sitzung des Kurses **Data Science**.
#
# Ziele:
# - die Arbeitsumgebung testen
# - erste Python-Befehle ausführen
# - einen ersten kleinen Datensatz mit `pandas` erzeugen
# - sehen, dass die Umgebung praktisch funktioniert

# %% [markdown]
# ## 1. Erster Test
#
# Führen Sie die nächste Zelle aus. Wenn die Ausgabe erscheint, funktioniert das Notebook.

# %%
print("Hello, business psychology")

# %% [markdown]
# ## 2. Rechnen mit Python
#
# Python kann sofort einfache Berechnungen ausführen.

# %%
2 + 2

# %% [markdown]
# ## 3. Variablen anlegen
#
# Variablen speichern Werte unter einem Namen.

# %%
age = 23
stress_score = 18
motivation_score = 21

print(age)
print(stress_score)
print(motivation_score)

# %% [markdown]
# ## 4. Listen und Mittelwert
#
# Hier verwenden wir eine Liste mit mehreren Werten und berechnen daraus einen Mittelwert.

# %%
scores = [12, 18, 15, 20, 17]

print("Anzahl:", len(scores))
print("Summe:", sum(scores))
print("Mittelwert:", sum(scores) / len(scores))

# %% [markdown]
# ## 5. Pandas importieren
#
# Jetzt prüfen wir, ob `pandas` verfügbar ist.

# %%
import pandas as pd

print(pd.__version__)

# %% [markdown]
# ## 6. Erster DataFrame
#
# Ein `DataFrame` ist eine tabellarische Datenstruktur. Sie ist für viele Aufgaben in Data Science zentral.

# %%
df = pd.DataFrame({
    "participant": [1, 2, 3, 4, 5],
    "motivation": [4, 5, 3, 4, 2],
    "stress": [2, 4, 5, 3, 4]
})

df

# %% [markdown]
# ## 7. Einfache Auswertung
#
# Jetzt berechnen wir die Mittelwerte zweier Spalten.

# %%
print("Mittelwert Motivation:", df["motivation"].mean())
print("Mittelwert Stress:", df["stress"].mean())

# %% [markdown]
# ## 8. Eine neue Spalte erzeugen
#
# Wir berechnen hier eine einfache Differenz zwischen Motivation und Stress.

# %%
df["difference"] = df["motivation"] - df["stress"]
df

# %% [markdown]
# ## 9. Kleine Reflexion
#
# Wenn alles funktioniert hat, ist Ihre Umgebung für die nächsten Schritte gut vorbereitet.
#
# Fragen für Sie:
# - Was war leicht?
# - Was war neu?
# - Was ist noch unklar?
